# %% [markdown]
# ### Working with Excel sheet.

# %%
import pandas as pd

# %%
data = pd.read_excel('./Datasets/FSI-2023-DOWNLOAD.xlsx')
data.head()
# Out:
#                      Country  Year Rank  Total  S1: Demographic Pressures  \
# 0                    Somalia  2023  1st  111.9                       10.0
# 1                      Yemen  2023  2nd  108.9                        9.6
# 2                South Sudan  2023  3rd  108.5                        9.7
# 3  Congo Democratic Republic  2023  4th  107.2                        9.7
# 4                      Syria  2023  5th  107.1                        7.4
#
#    S2: Refugees and IDPs  C3: Group Grievance  \
# 0                    9.0                  8.7
# 1                    9.6                  8.8
# 2                   10.0                  8.6
# 3                    9.8                  9.4
# 4                    9.1                  9.1
#
#    E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  \
# 0                               8.6                      9.1          9.5
# 1                               6.4                      7.9          9.9
# ...

# %% [markdown]
# #### `NOTE : ` We have one parameter in read_excel function which sheet_name where we can give the name of the sheet which we want to load.

# %% [markdown]
# ### Working with text file.

# %% [markdown]
# - It will have all those parameters that are used in csv file.

# %%
pd.read_csv('./Datasets/sample.txt')
# Out:
#       Name  Age   Department  Salary
# 0    Alice   28           HR   50000
# 1      Bob   34  Engineering   75000
# 2  Charlie   25    Marketing   45000
# 3    David   45  Engineering   90000
# 4      Eve   30      Finance   60000
